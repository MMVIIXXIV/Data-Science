# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cp_apps = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Second year first sem/DATA SCIENCE/W11/cc_approvals.data")
