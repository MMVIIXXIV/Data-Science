# %%
import pandas as pd
import matplotlib.pyplot as plt

years = [2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]

durations = [103,101,99,100,100,95,95,96,93,90]
movie_dict = {"years":years,"durations":durations}

# %%
#/content/drive/MyDrive/Colab Notebooks/DATA SCIENCE/W2 - Data Sets/netflix_data.csv

# %%
movie_dict
# Out:
# {'years': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#  'durations': [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]}

# %%
durations_df = pd.DataFrame(movie_dict)
print(durations_df)
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
fig = plt.figure()
plt.plot(durations_df['years'], durations_df['durations'])
plt.title('Netflix Movie Durations 2011-2020')
# Out:
# Text(0.5, 1.0, 'Netflix Movie Durations 2011-2020')

# %%
netflix_df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/DATA SCIENCE/W2 - Data Sets/netflix_data.csv')

# Print the first five rows of the DataFrame

netflix_df.head() # or netflix_df[:5] or netflix_df.iloc[:5,]
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_df_movies_only = netflix_df.query('type == "Movie"')
netflix_movies_col_subset = netflix_df_movies_only[['title','country','genre','release_year','duration']]
netflix_movies_col_subset.head()
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
# Create a figure and increase the figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
plt.scatter(netflix_movies_col_subset.release_year, netflix_movies_col_subset.duration,color='red')

# Create a title
plt.title("Movie Duration by Year of Release")

# Show the plot
plt.show()

# %%
# Filter for durations shorter than 60 minutes
short_movies = netflix_movies_col_subset[netflix_movies_col_subset['duration'] < 60]
#short_movies = netflix_movies_col_subset.query('duration < 60')

# Print the first 10 rows of short_movies
short_movies.head(10)
# Out:
#                                                  title        country  \
# 35                                           #Rucker50  United States
# 55                 100 Things to do Before High School  United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...            NaN
# 101                                  3 Seconds Divorce         Canada
# 146                                     A 3 Minute Hug         Mexico
# 162  A Christmas Special: Miraculous: Tales of Lady...         France
# 171                         A Family Reunion Christmas  United States
# 177                    A Go! Go! Cory Carson Christmas  United States
# 178                    A Go! Go! Cory Carson Halloween            NaN
# 179                  A Go! Go! Cory Carson Summer Camp            NaN
#
#              genre  release_year  duration
# 35   Documentaries          2016        56
# 55   Uncategorized          2014        44
# 67   Uncategorized          2017        37
# ...

# %%
colors = []

# Iterate over rows of netflix_movies_col_subset
for lab, row in netflix_movies_col_subset.iterrows() :
    if row['genre'] == "Children" :
        colors.append("red")
    elif row['genre'] == "Documentaries" :
        colors.append("blue")
    elif row['genre'] == "Stand-Up" :
        colors.append("green")
    else:
        colors.append("black")

# Inspect the first 10 values in your list
colors[:10]
# Out:
# ['black',
#  'black',
#  'black',
#  'black',
#  'black',
#  'black',
#  'black',
#  'black',
#  'black',
#  'blue']

# %%
# Set the figure style and initalize a new figure
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset.release_year, netflix_movies_col_subset.duration, color = colors)

# Create a title and axis labels
plt.title("Movie duration by year of release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")
# Out:
# Text(0, 0.5, 'Duration (min)')

# %% [markdown]
# **NO. 1.	Show the first five movies from USA with columns title, country, genre, release_year, duration.bold text**

# %%
#netflix_movies_col_subset = netflix_df_movies_only[['title','country','genre','release_year','duration']]

united_state=netflix_movies_col_subset[netflix_movies_col_subset['country'] =="United States" ]
united_state.head()

# #alt method
# united_state = netflix_movies_col_subset.query('country == "United States"')
# united_state.head()
# Out:
#    title        country               genre  release_year  duration
# 3      9  United States              Action          2009        80
# 4     21  United States              Dramas          2008       123
# 7    187  United States              Dramas          1997       119
# 10  1922  United States              Dramas          2017       103
# 14  3022  United States  Independent Movies          2019        91

# %% [markdown]
# **2.	Find average movie lengths (duration) of each genre. To get this to group the data by genre (use .groupby(‘genre’)) and find mean values. After that store the value in long_genre and print long_genre**

# %%
#long_genre = united_state.groupby("genre")["duration"].mean()>70  <--
long_genre = united_state.groupby("genre").mean()
output_long_genre= long_genre[long_genre['duration']>50]
print(output_long_genre)
# Out:
#                     release_year    duration
# genre
# Action               2008.922449  108.428571
# Children             2011.917241   79.441379
# Classic Movies       1968.404762  103.880952
# Comedies             2012.445122   96.576220
# Cult Movies          1990.111111   97.888889
# Documentaries        2016.128463   81.372796
# Dramas               2012.984085  104.965517
# Horror Movies        2014.414414   92.117117
# Independent Movies   2016.000000   98.000000
# Music                2016.600000   85.000000
# Romantic Movies      2017.500000   83.000000
# Sci-Fi               2011.833333  109.833333
# Stand-Up             2014.449275   67.256039
# Thrillers            2013.300000   97.775000
# <ipython-input-11-31db85f5eed3>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %% [markdown]
# **3	Plot horizontal bar chart (.barh) where x is genre and y is average duration. Set title to “US Movies Only” and x-axis title to “Average Minutes”. You may need .index to get the index column. For example,x = df.index**

# %%
long_genre = united_state.groupby("genre")[["duration"]].mean()
movie=long_genre[ long_genre['duration']>50]
plt.barh(movie.index,movie['duration'])
plt.title("US Movies Only")
plt.xlabel("Average Minutes")

# Show the plot
plt.show()

# %% [markdown]
# **4. Try also with the scatter plot.**

# %%
plt.scatter(x=movie,y=movie.index, alpha=0.5)
plt.title("US Movies Only")
plt.xlabel("Average Minutes")
# Out:
# Text(0.5, 0, 'Average Minutes')

# %%
# netflix_df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/DATA SCIENCE/W2 - Data Sets/netflix_data.csv')
# netflix_df_movies_only = netflix_df.query('type == "Movie"')

# netflix_movies_col_subset = netflix_df_movies_only[['title','country','genre','release_year','duration']]
# united_state=netflix_df_movies_only[netflix_movies_col_subset['country'] =="United States" ]

# long_genre = united_state.groupby("genre")["duration"].mean()
# #long_genre
# plt.barh(long_genre.index,long_genre)
# plt.title("US Movies Only")
# plt.xlabel("Average Minutes")

# # Show the plot
# plt.show()

# %% [markdown]
# **5.	Now find all Neftlix movies/TV show/etc. released between 2016 and 2020 with columns title, country, genre, release_year, duration.**

# %%
netflix_df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/DATA SCIENCE/W2 - Data Sets/netflix_data.csv')
netflix_df= netflix_df[['title','country','genre','release_year','duration']]

df_2016_2020=netflix_df[(netflix_df['release_year']>=2016) & (netflix_df['release_year']<=2020)]

df_2016_2020
# Out:
#                                         title         country  \
# 0                                          3%          Brazil
# 1                                        7:19          Mexico
# 5                                          46          Turkey
# 6                                         122           Egypt
# 8                                         706           India
# ...                                       ...             ...
# 7779                                Zona Rosa          Mexico
# 7780                                      Zoo           India
# 7784                        Zulu Man in Japan             NaN
# 7785                    Zumbo's Just Desserts       Australia
# 7786  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  United Kingdom
#
#                  genre  release_year  duration
# 0     International TV          2020         4
# 1               Dramas          2016        93
# 5     International TV          2016         1
# ...

# %% [markdown]
# **No.6 From 5., find out how many Movie/TV show/etc. do we have from each country. You need .groupby(‘country’).count()**

# %%
by_country=df_2016_2020.groupby('country').count()
by_country
# Out:
#                title  genre  release_year  duration
# country
# Argentina         55     55            55        55
# Australia         74     74            74        74
# Austria            7      7             7         7
# Bangladesh         2      2             2         2
# Belarus            1      1             1         1
# ...              ...    ...           ...       ...
# United States   1776   1776          1776      1776
# Uruguay            8      8             8         8
# Venezuela          1      1             1         1
# Vietnam            3      3             3         3
# Zimbabwe           1      1             1         1
#
# [78 rows x 4 columns]

# %% [markdown]
# **7.	Sort the dataframe by title and plot the following horizontal bar chart. Only first 10 countries (low to high).**

# %%
df=by_country.sort_values(by=['title'], ascending=False).head(10)
#.sort_values(by=['title'], ascending=True).tail(10)

plt.barh(df.index,df['title'])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# **8.Select only 2nd , 3rd and 4th countries and plot the pie chart.**

# %%
subset_of_df=df.iloc[1:4,:]
plt.pie(subset_of_df['title'], labels = subset_of_df.index, startangle = 90)
plt.show()

# %% [markdown]
# **9. Plot the following donut. Google how to do the donut plot. Also, Google how to show actual values and percentage in the chart.**

# %%
def func(pct):
  return "{:1.1f}%".format(pct)





fig = plt.figure(figsize=(30, 12.5))
# plt.pie(df['title'], labels=df.index, autopct="%1.1f%%",   startangle=90)

labels = df.index
values = df.iloc[:,0]

autotexts = plt.pie(values, labels=labels, autopct=lambda p: f'{p:.1f}% \n({int(round(p * sum(values) / 100.0))})',startangle=90, pctdistance=0.85)
#pctdistance : float, optional, default: 0.6
#The ratio between the center of each pie slice and the start of the text generated by autopct. Ignored if autopct is None.





circle = plt.Circle( (0,0), 0.65, color='white')
#plt.Circle( (x_location,y_location), size, color='color_name')


p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Number of titles released by top 10 countries')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt


my_circle = plt.Circle((0, 0), 0.9, color='white')


inner_labels = df.index

inner_counts = df['title']


inner_colors = plt.cm.Set3(np.arange(len(inner_labels)))


plt.rcParams['font.size'] = 8


def autopct_format(pct):

    count = int(pct/100 * np.sum(inner_counts))

    idx = np.where(df.index == inner_labels)[0][0]

    label = '{:.1f}%\n({:d})'.format(pct, count)

    print(f'{inner_labels[idx]}: {count} titles')

    return label


plt.pie(inner_counts, labels=inner_labels, autopct=autopct_format,

         colors=inner_colors, wedgeprops={'edgecolor': 'white'}, radius=2, startangle=90, labeldistance=1.12, pctdistance=0.85)


p = plt.gcf()

p.gca().add_artist(my_circle)


plt.show()
# Out:
# United States: 1776 titles
# United States: 434 titles
# United States: 359 titles
# United States: 185 titles
# United States: 148 titles
# United States: 146 titles
# United States: 139 titles
# United States: 135 titles
# United States: 94 titles
# United States: 74 titles
