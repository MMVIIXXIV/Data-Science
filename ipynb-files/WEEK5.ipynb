# %%
# /content/drive/MyDrive/Colab Notebooks/Second year first sem/DATA SCIENCE/W5/W5 - Data Sets and Solutions/Airlines_unclean.csv
# /content/drive/MyDrive/Colab Notebooks/Second year first sem/DATA SCIENCE/W5/W5 - Data Sets and Solutions/Salaries_with_date_of_response.csv
# /content/drive/MyDrive/Colab Notebooks/Second year first sem/DATA SCIENCE/W5/W5 - Data Sets and Solutions/Salary_Rupee_USD.csv
# /content/drive/MyDrive/Colab Notebooks/Second year first sem/DATA SCIENCE/W5/W5 - Data Sets and Solutions/divorce.csv
